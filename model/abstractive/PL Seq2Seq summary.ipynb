# %%
# !pip install rouge
# Out:
# Requirement already satisfied: rouge in /opt/anaconda3/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from rouge) (1.14.0)

# %%
import math
import numpy as np
import pandas as pd
import os
import random
import re
import spacy
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.nn.utils import clip_grad_norm_
from torch.autograd import Variable

from glob import glob
from sklearn.model_selection import train_test_split
from tqdm import notebook, tqdm_notebook
from torchtext.data import Field, BucketIterator, TabularDataset

from rouge import Rouge

# %% [markdown]
# ## Load data

# %%
glob('../../data/pl_articles/*')
# Out:
# ['../../data/pl_articles/val.csv',
#  '../../data/pl_articles/test.csv',
#  '../../data/pl_articles/train.csv']

# %%
nlp = spacy.load('pl_spacy_model', disable=['ner', 'parser'])

# %%
def tokenize_pl(text):
    text = re.sub(r"(\„|\”|\–|\\)", '', str(text))
    text = re.sub(r"(\/)", ' ', str(text))
    text = re.sub("[0-9]+", " NUM ", str(text)) # hide numbers
    text = re.sub("\s+", ' ', str(text))
    return [tok.text for tok in nlp.tokenizer(text)]

# %% [markdown]
# ## Get dataset

# %%
def load_dataset(batch_size):
    TEXT = Field(tokenize=tokenize_pl, include_lengths=True, tokenizer_language='pl',
                 init_token='<sos>', eos_token='<eos>')
    SUMMARY = Field(tokenize=tokenize_pl, include_lengths=True, tokenizer_language='pl',
                    init_token='<sos>', eos_token='<eos>')
    train, val, test = TabularDataset.splits(
        skip_header=True, 
        path='../../data/pl_articles/', format='csv', 
        fields=[('index', None), ('lead', SUMMARY), ('text', TEXT)],
        train='train.csv', validation='val.csv', test='test.csv'
    )
    TEXT.build_vocab(train, min_freq=2)
#     SUMMARY.build_vocab(train, min_freq=2)
    SUMMARY.vocab = TEXT.vocab
    train_iter, val_iter, test_iter = BucketIterator.splits(
        (train, val, test), batch_size=batch_size, repeat=False, sort_key=lambda x: len(x.text), sort_within_batch=False
    )
    return train_iter, val_iter, test_iter, TEXT, SUMMARY

# %%
batch_size = 32

# %%
train_iter, val_iter, test_iter, TEXT, SUMMARY = load_dataset(batch_size)

# %%
len(TEXT.vocab.stoi)
# Out:
# 193831

# %%
TEXT.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x1ad747690>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              '<sos>': 2,
#              '<eos>': 3,
#              '.': 4,
#              '<': 5,
#              '>': 6,
#              'num': 7,
#              'w': 8,
#              'z': 9,
#              'na': 10,
#              'i': 11,
#              'być': 12,
#              'się': 13,
#              'nie': 14,
#              'to': 15,
#              'do': 16,
#              'on': 17,
#              'że': 18,
#              'który': 19,
#              'ten': 20,
#              'mieć': 21,
#              'o': 22,
#              'a': 23,
#              'po': 24,
#              'ale': 25,
#              'rok': 26,
#              '–': 27,
#              'od': 28,
#              'móc': 29,
#              'jak': 30,
#              'mecz': 31,
#              'co': 32,
#              'za': 33,
#              'dla': 34,
#              'już': 35,
#              'bardzo': 36,
#              'będzie': 37,
#              'pierwszy': 38,
#              'swój': 39,
#              'jednak': 40,
#              'dobry': 41,
#              'przez': 42,
#              'oraz': 43,
#              'tylko': 44,
#              'jeden': 45,
#              'nowy': 46,
#              'taki': 47,
#              'tak': 48,
#              'zostać': 49,
#              'czy': 50,
#              'dwa': 51,
#              'też': 52,
#              'miejsce': 53,
#              'przed': 54,
#              'czas': 55,
#              'punkt': 56,
#              'my': 57,
#              'raz': 58,
#              'sezon': 59,
#              'nasz': 60,
#              'drugi': 61,
#              'wielki': 62,
#              '”': 63,
#              'zespół': 64,
#              'także': 65,
#              'drużyna': 66,
#              'bo': 67,
#              'jeszcze': 68,
#              'trener': 69,
#              'sam': 70,
#              'mówić': 71,
#              'inny': 72,
#              'gra': 73,
#              'zawodnik': 74,
#              'ostatni': 75,
#              'złoty': 76,
#              'ja': 77,
#              'Polska': 78,
#              'dobrze': 79,
#              'chcieć': 80,
#              'spotkanie': 81,
#              'grać': 82,
#              'polski': 83,
#              'kolejny': 84,
#              'można': 85,
#              'liga': 86,
#              'cały': 87,
#              'wszystko': 88,
#              'kilka': 89,
#              'przy': 90,
#              'wszystek': 91,
#              'by': 92,
#              'pod': 93,
#              'każdy': 94,
#              'również': 95,
#              'jeśli': 96,
#              'nawet': 97,
#              'trzy': 98,
#              'świat': 99,
#              'wiele': 100,
#              'będą': 101,
#              'sobie': 102,
#              'minuta': 103,
#              'wygrać': 104,
#              'koniec': 105,
#              'strona': 106,
#              'lub': 107,
#              'wynik': 108,
#              'gdy': 109,
#              'musić': 110,
#              'niż': 111,
#              'osoba': 112,
#              'dzień': 113,
#              'teraz': 114,
#              'bez': 115,
#              'problem': 116,
#              'ważny': 117,
#              'jaki': 118,
#              'więc': 119,
#              'firma': 120,
#              'sytuacja': 121,
#              'milion': 122,
#              'u': 123,
#              'praca': 124,
#              'piłka': 125,
#              'duży': 126,
#              'wysoki': 127,
#              'podczas': 128,
#              'zdobyć': 129,
#              'powiedzieć': 130,
#              'początek': 131,
#              'jako': 132,
#              'kibic': 133,
#              'wiedzieć': 134,
#              'proc.': 135,
#              'prowadzić': 136,
#              'rywal': 137,
#              'stać': 138,
#              'aby': 139,
#              'zagrać': 140,
#              'klub': 141,
#              'grupa': 142,
#              'znaleźć': 143,
#              'więcej': 144,
#              'mistrzostwo': 145,
#              'dziecko': 146,
#              'trzeci': 147,
#              'piłkarz': 148,
#              'bramka': 149,
#              'mistrz': 150,
#              'zmiana': 151,
#              'sprawa': 152,
#              'akcja': 153,
#              'dużo': 154,
#              'kiedy': 155,
#              'czyli': 156,
#              'część': 157,
#              'zacząć': 158,
#              'mój': 159,
#              'trzeba': 160,
#              'dzięki': 161,
#              'sposób': 162,
#              'kluba': 163,
#              'aż': 164,
#              'nad': 165,
#              'dać': 166,
#              'szansa': 167,
#              'samochód': 168,
#              'kierowca': 169,
#              'turniej': 170,
#              'choć': 171,
#              'oba': 172,
#              'r.': 173,
#              'tydzień': 174,
#              'cztery': 175,
#              'właśnie': 176,
#              'polak': 177,
#              'przypadek': 178,
#              'zobaczyć': 179,
#              'gdzie': 180,
#              'zwycięstwo': 181,
#              'start': 182,
#              'zrobić': 183,
#              'gol': 184,
#              'wcześnie': 185,
#              'mały': 186,
#              'późno': 187,
#              'reprezentacja': 188,
#              'miesiąc': 189,
#              'godzina': 190,
#              'często': 191,
#              'trafić': 192,
#              'finał': 193,
#              'żaden': 194,
#              'mało': 195,
#              'udać': 196,
#              'dlatego': 197,
#              'poziom': 198,
#              'ponad': 199,
#              'miasto': 200,
#              'należeć': 201,
#              'spółka': 202,
#              'prezes': 203,
#              'sport': 204,
#              'siebie': 205,
#              'walka': 206,
#              'm.in.': 207,
#              'skład': 208,
#              'żeby': 209,
#              'szybko': 210,
#              'chwila': 211,
#              '’': 212,
#              'pojawić': 213,
#              'informacja': 214,
#              'musieć': 215,
#              'prosty': 216,
#              'wtedy': 217,
#              'dopiero': 218,
#              'cena': 219,
#              'projekt': 220,
#              'pozycja': 221,
#              'moment': 222,
#              'uwaga': 223,
#              'droga': 224,
#              'coś': 225,
#              'gracz': 226,
#              'nica': 227,
#              'trening': 228,
#              'decyzja': 229,
#              'gospodarz': 230,
#              '%': 231,
#              'tys.': 232,
#              'temu': 233,
#              'robić': 234,
#              'własny': 235,
#              'możliwość': 236,
#              'tam': 237,
#              'przegrać': 238,
#              'forma': 239,
#              'liczyć': 240,
#              'udział': 241,
#              'stal': 242,
#              'rzut': 243,
#              'boisko': 244,
#              'rozpocząć': 245,
#              'czekać': 246,
#              'seria': 247,
#              'bank': 248,
#              'młody': 249,
#              'europ': 250,
#              'oczywiście': 251,
#              'wyglądać': 252,
#              'główny': 253,
#              'pewny': 254,
#              'kraj': 255,
#              'kadra': 256,
#              'rynek': 257,
#              'tor': 258,
#              'klient': 259,
#              'godz.': 260,
#              'wydawać': 261,
#              'historia': 262,
#              'gość': 263,
#              'okazać': 264,
#              'pokonać': 265,
#              'euro': 266,
#              'aplikacja': 267,
#              'pewno': 268,
#              'Stala': 269,
#              'kto': 270,
#              'zakończyć': 271,
#              '+': 272,
#              'tyle': 273,
#              'zawód': 274,
#              'dziś': 275,
#              'zawsze': 276,
#              'odbyć': 277,
#              'warto': 278,
#              'człowiek': 279,
#              'mimo': 280,
#              'sobota': 281,
#              'dom': 282,
#              'zły': 283,
#              'runda': 284,
#              'powód': 285,
#              'np.': 286,
#              'natomiast': 287,
#              'produkt': 288,
#              'chodzić': 289,
#              'niedziela': 290,
#              'pięć': 291,
#              'karny': 292,
#              'film': 293,
#              'zmienić': 294,
#              'warszawa': 295,
#              'walczyć': 296,
#              'okazja': 297,
#              'sportowy': 298,
#              'poprzedni': 299,
#              'pokazać': 300,
#              'połów': 301,
#              'mieść': 302,
#              'atak': 303,
#              'obecnie': 304,
#              'dodać': 305,
#              'tu': 306,
#              'piątka': 307,
#              'wzgląd': 308,
#              'bliski': 309,
#              'rozwiązanie': 310,
#              'przerwa': 311,
#              'rozegrać': 312,
#              'puchar': 313,
#              'coraz': 314,
#              'długi': 315,
#              'pracować': 316,
#              'marka': 317,
#              'awans': 318,
#              'ekipa': 319,
#              'według': 320,
#              'potem': 321,
#              'medal': 322,
#              'góra': 323,
#              'niestety': 324,
#              'naprawdę': 325,
#              'między': 326,
#              'ciekawy': 327,
#              'zająć': 328,
#              'albo': 329,
#              'lider': 330,
#              'piotr': 331,
#              'rucho': 332,
#              'cieszyć': 333,
#              'trudny': 334,
#              'jakiś': 335,
#              'przewaga': 336,
#              'oznaczać': 337,
#              'wyścig': 338,
#              'liczba': 339,
#              'poza': 340,
#              'x': 341,
#              'umowa': 342,
#              'trochę': 343,
#              'wrócić': 344,
#              'oferta': 345,
#              'prawo': 346,
#              'stań': 347,
#              'urządzenie': 348,
#              'pieniądz': 349,
#              'różny': 350,
#              'błąd': 351,
#              'tytuł': 352,
#              'porażka': 353,
#              'dojść': 354,
#              'trudno': 355,
#              'sukces': 356,
#              'auto': 357,
#              'może': 358,
#              'wersja': 359,
#              'dotyczyć': 360,
#              'bieg': 361,
#              'potrafić': 362,
#              'kolejka': 363,
#              'wciąż': 364,
#              'dodawać': 365,
#              'działać': 366,
#              'temat': 367,
#              'czwarty': 368,
#              'ręka': 369,
#              'stadion': 370,
#              'szybki': 371,
#              'nikt': 372,
#              'zajmować': 373,
#              'większość': 374,
#              'facebook': 375,
#              'rzeszów': 376,
#              'program': 377,
#              'plan': 378,
#              'zdjęcie': 379,
#              'pamiętać': 380,
#              'będziemy': 381,
#              '…': 382,
#              'numer': 383,
#              'otrzymać': 384,
#              'kobieta': 385,
#              'strata': 386,
#              'wybrać': 387,
#              'serwis': 388,
#              'koleja': 389,
#              'dawać': 390,
#              'pomoc': 391,
#              'dostać': 392,
#              'życie': 393,
#              'nadzieja': 394,
#              'Roberta': 395,
#              'głowa': 396,
#              'widzieć': 397,
#              'ul.': 398,
#              'bowiem': 399,
#              'wolny': 400,
#              'stary': 401,
#              'wśród': 402,
#              'mocno': 403,
#              'kontuzja': 404,
#              'model': 405,
#              'wzrost': 406,
#              'dzienie': 407,
#              'przygotować': 408,
#              'ii': 409,
#              'nieco': 410,
#              'użytkownik': 411,
#              'około': 412,
#              'prowadzenie': 413,
#              'konto': 414,
#              'tabela': 415,
#              'ani': 416,
#              'stracić': 417,
#              'wykorzystać': 418,
#              'azs': 419,
#              'zdecydować': 420,
#              'rzecz': 421,
#              'męski': 422,
#              'cel': 423,
#              'jeżeli': 424,
#              'daleko': 425,
#              'uważać': 426,
#              'tomasz': 427,
#              'rozgrywki': 428,
#              'kilometr': 429,
#              'produkcja': 430,
#              'niski': 431,
#              'znajdywać': 432,
#              'linia': 433,
#              'metrum': 434,
#              'michał': 435,
#              'trwać': 436,
#              'świetny': 437,
#              'zbyt': 438,
#              'czerwony': 439,
#              'smartfon': 440,
#              'stan': 441,
#              'kontrakt': 442,
#              'mocny': 443,
#              'systema': 444,
#              'sprzedaż': 445,
#              'pełny': 446,
#              'okres': 447,
#              'środek': 448,
#              'obecny': 449,
#              'nadal': 450,
#              'korzystać': 451,
#              'siła': 452,
#              'jechać': 453,
#              'zdanie': 454,
#              'działanie': 455,
#              'czarny': 456,
#              'długo': 457,
#              'rywalizacja': 458,
#              'jazda': 459,
#              'polska': 460,
#              'możliwy': 461,
#              'dostępny': 462,
#              'igrzysko': 463,
#              'łukasz': 464,
#              'efekt': 465,
#              'rozwój': 466,
#              'finansowy': 467,
#              'dodatkowy': 468,
#              'odcinek': 469,
#              'wybór': 470,
#              'ktoś': 471,
#              'medium': 472,
#              'wypadek': 473,
#              'jedyny': 474,
#              'ok.': 475,
#              'legia': 476,
#              'Pawła': 477,
#              'zasada': 478,
#              'sześć': 479,
#              'pozwolić': 480,
#              'rząd': 481,
#              'sieć': 482,
#              'wartość': 483,
#              'kariera': 484,
#              'ile': 485,
#              'słaby': 486,
#              'zarówno': 487,
#              'sklep': 488,
#              'ponieważ': 489,
#              'impreza': 490,
#              'wiadomo': 491,
#              'bramkarz': 492,
#              'rola': 493,
#              'przyznać': 494,
#              'czuć': 495,
#              'fan': 496,
#              'rozmowa': 497,
#              'wziąć': 498,
#              'dość': 499,
#              'telefon': 500,
#              'podobny': 501,
#              'hala': 502,
#              'konkurs': 503,
#              'gdyby': 504,
#              'marcin': 505,
#              'znacznie': 506,
#              'znany': 507,
#              'Rzeszów': 508,
#              'związek': 509,
#              'szczęście': 510,
#              'występ': 511,
#              'koszt': 512,
#              'play': 513,
#              'były': 514,
#              'woda': 515,
#              's': 516,
#              'trasa': 517,
#              'brakować': 518,
#              'zielony': 519,
#              'budynek': 520,
#              'ogromny': 521,
#              'sekunda': 522,
#              'ekstraklasa': 523,
#              'brak': 524,
#              'pan': 525,
#              'pora': 526,
#              'wynikać': 527,
#              'pomysł': 528,
#              'niemal': 529,
#              'ty': 530,
#              'kwarta': 531,
#              'serial': 532,
#              'obrona': 533,
#              'strzelić': 534,
#              'wyjazd': 535,
#              'specjalny': 536,
#              'olimpijski': 537,
#              'pozwalać': 538,
#              'widać': 539,
#              'europejski': 540,
#              'fakt': 541,
#              'google': 542,
#              'm.': 543,
#              'jeździć': 544,
#              'Krzysztofa': 545,
#              'badanie': 546,
#              'pomóc': 547,
#              'sprawdzić': 548,
#              'unia': 549,
#              'wygrana': 550,
#              'znów': 551,
#              'producent': 552,
#              'jedynie': 553,
#              'przecież': 554,
#              'ramy': 555,
#              'daleki': 556,
#              'miliard': 557,
#              'ostatnio': 558,
#              'pytanie': 559,
#              'obrońca': 560,
#              'podkreślać': 561,
#              'chyba': 562,
#              'podobnie': 563,
#              'letny': 564,
#              'oko': 565,
#              'Polak': 566,
#              'Kraków': 567,
#              'blisko': 568,
#              'tysiąc': 569,
#              'powinien': 570,
#              'brać': 571,
#              'sprzęt': 572,
#              'marzec': 573,
#              'myślić': 574,
#              'pge': 575,
#              'wysokość': 576,
#              'ekran': 577,
#              'ciąg': 578,
#              'przykład': 579,
#              'znać': 580,
#              'kolega': 581,
#              'łatwo': 582,
#              'pracownik': 583,
#              'ulica': 584,
#              'słowo': 585,
#              'tłumaczyć': 586,
#              'wystarczyć': 587,
#              'gwiazda': 588,
#              'pozostały': 589,
#              'sobą': 590,
#              'mieszkaniec': 591,
#              'mężczyzna': 592,
#              'występować': 593,
#              'zarząd': 594,
#              'drogi': 595,
#              'sokół': 596,
#              'przyszłość': 597,
#              'szczególnie': 598,
#              'typ': 599,
#              'sędzia': 600,
#              'tutaj': 601,
#              'zaczynać': 602,
#              'prawda': 603,
#              'Kamila': 604,
#              'wieko': 605,
#              'oprócz': 606,
#              'przejść': 607,
#              'pewnie': 608,
#              'f': 609,
#              'czerwiec': 610,
#              'wynosić': 611,
#              'odpowiedni': 612,
#              'nigdy': 613,
#              'środa': 614,
#              'podjąć': 615,
#              'styczeń': 616,
#              'internet': 617,
#              'starać': 618,
#              'inwestycja': 619,
#              'napastnik': 620,
#              'wykonać': 621,
#              'zupełnie': 622,
#              'wystąpić': 623,
#              'półfinał': 624,
#              'Appel': 625,
#              'próbować': 626,
#              'wymagać': 627,
#              'Macieja': 628,
#              'ostatecznie': 629,
#              'faza': 630,
#              'spodziewać': 631,
#              'funkcja': 632,
#              'postać': 633,
#              'zdecydowanie': 634,
#              'wygrywać': 635,
#              'źle': 636,
#              'zawodniczka': 637,
#              'pojechać': 638,
#              'szef': 639,
#              'pole': 640,
#              'kończyć': 641,
#              'zmierzyć': 642,
#              'twój': 643,
#              'obiekt': 644,
#              'stanowić': 645,
#              'rynka': 646,
#              'seta': 647,
#              'zadanie': 648,
#              'powrót': 649,
#              'budowa': 650,
#              'wpływ': 651,
#              'pewność': 652,
#              'sporo': 653,
#              'materiał': 654,
#              'wskazywać': 655,
#              'zaledwie': 656,
#              'najpierw': 657,
#              'dane': 658,
#              'oglądać': 659,
#              'stwierdzić': 660,
#              'dlaczego': 661,
#              'wysoko': 662,
#              'raczej': 663,
#              'widz': 664,
#              'wrzesień': 665,
#              'zabraknąć': 666,
#              'system': 667,
#              'noga': 668,
#              'Kubic': 669,
#              'procent': 670,
#              'końcówka': 671,
#              'etap': 672,
#              'szukać': 673,
#              'awansować': 674,
#              'premiera': 675,
#              'Kraka': 676,
#              'mateusz': 677,
#              'kwota': 678,
#              'rada': 679,
#              'zwłaszcza': 680,
#              'the': 681,
#              'skończyć': 682,
#              'ligowy': 683,
#              'trakt': 684,
#              'pokazywać': 685,
#              'podstawowy': 686,
#              'wyniść': 687,
#              'Niemcy': 688,
#              'posiadać': 689,
#              'centrum': 690,
#              'resovia': 691,
#              'sport.pl': 692,
#              'klasa': 693,
#              'koszykarz': 694,
#              'czytać': 695,
#              'internetowy': 696,
#              'rodzina': 697,
#              'przyszły': 698,
#              'jakość': 699,
#              'wraz': 700,
#              'dziennikarz': 701,
#              'powstać': 702,
#              'zdrowie': 703,
#              'zapowiadać': 704,
#              'oficjalny': 705,
#              'grzegorz': 706,
#              'silny': 707,
#              'prawie': 708,
#              'stworzyć': 709,
#              'przygotowanie': 710,
#              'planować': 711,
#              'element': 712,
#              'inwestor': 713,
#              'Wisła': 714,
#              'szkoleniowiec': 715,
#              's.': 716,
#              'warunek': 717,
#              'twierdzić': 718,
#              'test': 719,
#              'kupić': 720,
#              'potrzebować': 721,
#              'źródło': 722,
#              'kwestia': 723,
#              'kierunek': 724,
#              'kategoria': 725,
#              'dieta': 726,
#              'maj': 727,
#              'następnie': 728,
#              'przepis': 729,
#              'zapewnić': 730,
#              '“': 731,
#              'dyrektor': 732,
#              'e': 733,
#              'spory': 734,
#              'letni': 735,
#              'teren': 736,
#              'junior': 737,
#              'wydarzenie': 738,
#              'poznanie': 739,
#              'głównie': 740,
#              'Śląsko': 741,
#              'będę': 742,
#              'stylo': 743,
#              'uzyskać': 744,
#              'pojawiać': 745,
#              'poważny': 746,
#              'oferować': 747,
#              'siedem': 748,
#              'Adamy': 749,
#              'krok': 750,
#              'dodatkowo': 751,
#              'poniedziałek': 752,
#              'przeciwnik': 753,
#              'zamiast': 754,
#              'informować': 755,
#              'tworzyć': 756,
#              'remis': 757,
#              'platforma': 758,
#              'tuż': 759,
#              'właściciel': 760,
#              'trefl': 761,
#              'bilet': 762,
#              'iść': 763,
#              'jednocześnie': 764,
#              'świetnie': 765,
#              'wykorzystywać': 766,
#              'popularny': 767,
#              'niemiec': 768,
#              'osiem': 769,
#              'Rafały': 770,
#              'lipiec': 771,
#              'wprowadzić': 772,
#              'transfer': 773,
#              'współpraca': 774,
#              'policja': 775,
#              'ilość': 776,
#              'prawdziwy': 777,
#              'wówczas': 778,
#              'potrzeba': 779,
#              'grudzień': 780,
#              'przynajmniej': 781,
#              'skuteczny': 782,
#              'zapewniać': 783,
#              'osiągnąć': 784,
#              'zmieniać': 785,
#              'usługa': 786,
#              'sierpień': 787,
#              'rozgrywać': 788,
#              'pisać': 789,
#              'odpowiadać': 790,
#              'zaś': 791,
#              'uznać': 792,
#              'pojazd': 793,
#              'prezentować': 794,
#              'lista': 795,
#              'piąty': 796,
#              'październik': 797,
#              'doświadczenie': 798,
#              'trenować': 799,
#              'nagroda': 800,
#              'ubiegły': 801,
#              'strefa': 802,
#              'próba': 803,
#              'szkoła': 804,
#              'światowy': 805,
#              'dystans': 806,
#              'kartka': 807,
#              'zależeć': 808,
#              'miejski': 809,
#              'rzeszowski': 810,
#              'wrażenie': 811,
#              'wtorek': 812,
#              'żyto': 813,
#              'stopień': 814,
#              'bohater': 815,
#              'lewandowski': 816,
#              'relacja': 817,
#              'tym': 818,
#              'władza': 819,
#              'skok': 820,
#              'off': 821,
#              'usa': 822,
#              'różnica': 823,
#              'klasyfikacja': 824,
#              'listopad': 825,
#              'inaczej': 826,
#              'technologia': 827,
#              'zgodnie': 828,
#              'zakup': 829,
#              'blok': 830,
#              'organizm': 831,
#              'tracić': 832,
#              'układ': 833,
#              'wywalczyć': 834,
#              'napisać': 835,
#              'amerykański': 836,
#              'miejscowy': 837,
#              'pozostać': 838,
#              'kosztować': 839,
#              'kwiecień': 840,
#              'istnieć': 841,
#              'wniosek': 842,
#              'poinformować': 843,
#              'czwartka': 844,
#              'asseco': 845,
#              'krótki': 846,
#              'biało': 847,
#              'podstawa': 848,
#              'zresztą': 849,
#              'dokładnie': 850,
#              'emocja': 851,
#              'potrzebny': 852,
#              'stawka': 853,
#              'proces': 854,
#              'łódź': 855,
#              'silnik': 856,
#              'indywidualny': 857,
#              'przyjść': 858,
#              'kilogram': 859,
#              'Jakuby': 860,
#              'rekord': 861,
#              'przypominać': 862,
#              'ciężki': 863,
#              'dodatek': 864,
#              'przestrzeń': 865,
#              'luty': 866,
#              'warunki': 867,
#              'Włochy': 868,
#              'bezpieczeństwo': 869,
#              'lubić': 870,
#              'twórca': 871,
#              'tzw.': 872,
#              'komputer': 873,
#              'rajd': 874,
#              'cela': 875,
#              'termin': 876,
#              'zakończenie': 877,
#              'sprawić': 878,
#              'wracać': 879,
#              'żużlowiec': 880,
#              'podopieczny': 881,
#              'wole': 882,
#              'biały': 883,
#              'wierzyć': 884,
#              'partia': 885,
#              'razem': 886,
#              'ogół': 887,
#              'mielec': 888,
#              'roczek': 889,
#              'oddać': 890,
#              'dzisiaj': 891,
#              'następny': 892,
#              'startować': 893,
#              'resovii': 894,
#              'organizacja': 895,
#              'wyłącznie': 896,
#              'postawić': 897,
#              'mniej': 898,
#              'przeciwko': 899,
#              'podać': 900,
#              'pojedynka': 901,
#              'rodzaj': 902,
#              'podpisać': 903,
#              'dawny': 904,
#              'reprezentant': 905,
#              'faworyt': 906,
#              'powinno': 907,
#              'nazwa': 908,
#              'pomiędzy': 909,
#              'energia': 910,
#              'plus': 911,
#              'środkowy': 912,
#              'suma': 913,
#              'pozostawać': 914,
#              'centymetr': 915,
#              'granica': 916,
#              'niewiele': 917,
#              'pójść': 918,
#              'real': 919,
#              'dołączyć': 920,
#              '..': 921,
#              'postanowić': 922,
#              'łatwy': 923,
#              'andrzej': 924,
#              'średni': 925,
#              'spotkać': 926,
#              'zachowanie': 927,
#              'karta': 928,
#              'myśl': 929,
#              'wsparcie': 930,
#              'lewy': 931,
#              'android': 932,
#              'zaplanować': 933,
#              'no': 934,
#              'zbiórka': 935,
#              'przedstawiciel': 936,
#              'konferencja': 937,
#              'dziać': 938,
#              'przeprowadzić': 939,
#              'piękny': 940,
#              'istotny': 941,
#              'zaliczyć': 942,
#              'ciało': 943,
#              'fundusz': 944,
#              'radzić': 945,
#              'pies': 946,
#              'chociaż': 947,
#              'potwierdzić': 948,
#              'wideo': 949,
#              'de': 950,
#              'konkurencja': 951,
#              'strzała': 952,
#              'zastąpić': 953,
#              'obok': 954,
#              'mobilny': 955,
#              'techniczny': 956,
#              'asysta': 957,
#              'Dawidy': 958,
#              'wspomnieć': 959,
#              'kluczowy': 960,
#              'prawdopodobnie': 961,
#              'rzucić': 962,
#              'krajowy': 963,
#              'weekend': 964,
#              'portal': 965,
#              'bezpieczny': 966,
#              'wrocław': 967,
#              'barwy': 968,
#              'team': 969,
#              'zapłacić': 970,
#              'zawierać': 971,
#              'zadowolony': 972,
#              'prezydent': 973,
#              'usługi': 974,
#              'sprawiać': 975,
#              'dostęp': 976,
#              'odpowiedź': 977,
#              'stosować': 978,
#              'stacja': 979,
#              'iphone': 980,
#              'przypomnieć': 981,
#              'bartosz': 982,
#              'zysk': 983,
#              'złożyć': 984,
#              'zatrzymać': 985,
#              'udany': 986,
#              'wisła': 987,
#              'zdobywać': 988,
#              'granda': 989,
#              'kontrola': 990,
#              'ranking': 991,
#              'aparat': 992,
#              'propozycja': 993,
#              'bronić': 994,
#              'spaść': 995,
#              'publiczny': 996,
#              'kolor': 997,
#              'zaprezentować': 998,
#              'światło': 999,
#              ...})

# %%
def indices_from_text(text, lang=TEXT):
    indices = []
    for word in text.strip().split(' '):
        indices.append(lang.vocab.stoi[word])
    return Variable(torch.LongTensor(indices)).cuda()

# %%
def text_from_indices(indices, lang=TEXT):
    text = ""
    for element in indices:
        if type(element) is torch.Tensor:
            text += lang.vocab.itos[element.item()] + " "
        else:
            text += lang.vocab.itos[element] + " "
    return text

# %% [markdown]
# #### Random text

# %%
batch = next(iter(train_iter))

# %%
text_from_indices(batch.text[0].transpose(0, 1)[-1])
# Out:
# '<sos> nowy linia autobusowy mieć numer 57 . autobus będzie ruszać z dworzec lokalny w Rzeszów a kurs zakończyć w Łańcut podzwierzyniec . kurs z Rzeszów dworzec lokalny wykonywać będą w dzień roboczy o godz. kurs z Łańcut podzwierzyniec wykonywać będą w dzień roboczy o godz. pełny rozkład przystanek dostępny na strona ztm rzeszów . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> '

# %% [markdown]
# #### Random summary

# %%
text_from_indices(batch.lead[0].transpose(0, 1)[-1])
# Out:
# '<sos> mieszkaniec Łańcut będą móc od dzisiaj wybrać się do Rzeszów autobus linia mpk . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> '

# %% [markdown]
# ## Seq2Seq model

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, n_layers=1, dropout=0.1):
        super(EncoderRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.gru = nn.GRU(embedding_size, hidden_size, n_layers,
                          dropout=dropout, bidirectional=True)

    def forward(self, sequence, hidden=None):
        embedding_output = self.embedding(sequence).cuda() # max_text_len x batch_size x embedding_size
        encoder_outputs, hidden = self.gru(embedding_output, hidden)
        # hidden: bidirectional x batch_size x hidden_size
        # output: max_text_len x batch_size x bidirectional * hidden_size
        encoder_outputs = encoder_outputs[:, :, :self.hidden_size] + encoder_outputs[:, :, self.hidden_size:]
        # output: max_text_len x batch_size x hidden_size
        encoder_outputs = encoder_outputs.cuda()
        return encoder_outputs, hidden

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.hidden_size = hidden_size
        self.attention = nn.Linear(hidden_size * 2, hidden_size)
        self.v = nn.Parameter(torch.rand(hidden_size))
        stdv = 1. / math.sqrt(self.v.size(0))
        self.v.data.uniform_(-stdv, stdv)

    def forward(self, hidden, encoder_outputs):
        timestep = encoder_outputs.size(0)
        h = hidden.repeat(timestep, 1, 1).transpose(0, 1)
        encoder_outputs = encoder_outputs.transpose(0, 1) 
        attn_energies = self.score(h, encoder_outputs) # batch_size x t x hidden
        return F.softmax(attn_energies, dim=1).unsqueeze(1) # batch_size x t

    def score(self, hidden, encoder_outputs):
        # batch_size x t x 2*hidden -> batch_size x t x hidden
        energy = torch.tanh(self.attention(torch.cat([hidden, encoder_outputs], 2)))
        energy = energy.transpose(1, 2) # batch_size x t x 2*hidden -> batch_size x t x hidden
        v = self.v.repeat(encoder_outputs.size(0), 1).unsqueeze(1) # batch_size x 1 x hidden
        energy = torch.bmm(v, energy) # batch_size x 1 x t
        return energy.squeeze(1) # batch_size x t

# %%
class DecoderRNN(nn.Module):
    def __init__(self, embedding_size, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(DecoderRNN, self).__init__()
        self.embedding_size = embedding_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        self.embedding = nn.Embedding(output_size, embedding_size)
        self.dropout = nn.Dropout(dropout, inplace=True)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(hidden_size + embedding_size, hidden_size, n_layers, dropout=dropout)
        self.output = nn.Linear(hidden_size * 2, output_size)

    def forward(self, sequence, hidden, encoder_outputs):
        # Get the embedding of the current input word (last output word)
        embedding_output = self.embedding(sequence).unsqueeze(0).cuda()  # 1 x batch_size x n
        embedding_output = self.dropout(embedding_output)
        # Calculate attention weights and apply to encoder outputs
        attention_weights = self.attention(hidden[-1], encoder_outputs).cuda()
        context = attention_weights.bmm(encoder_outputs.transpose(0, 1)) # batch_size x 1 x n
        context = context.transpose(0, 1)  # (1,B,N)
        # Combine embedded input word and attended context, run through RNN
        decoder_input = torch.cat([embedding_output, context], 2)
        decoder_output, hidden = self.gru(decoder_input, hidden)
        decoder_output = decoder_output.squeeze(0)  # (1,B,N) -> (B,N)
        context = context.squeeze(0)
        decoder_output = self.output(torch.cat([decoder_output, context], 1))
        decoder_output = F.log_softmax(decoder_output, dim=1)
        return decoder_output, hidden, attention_weights

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, text, summary, teacher_forcing_ratio=0.5):
        batch_size = text.size(1)
        max_len = summary.size(0)
        vocab_size = self.decoder.output_size

        encoder_output, hidden = self.encoder(text)
        hidden = hidden[:self.decoder.n_layers]
        output = Variable(summary.data[0, :]).cuda()  # sos
        
        outputs = Variable(torch.zeros(max_len, batch_size, vocab_size)).cuda()
        for t in range(1, max_len):
            output, hidden, attention_weights = self.decoder(
                    output, hidden, encoder_output)
            outputs[t] = output
            is_teacher = random.random() < teacher_forcing_ratio
            top_first = output.data.max(1)[1]
            output = Variable(summary.data[t] if is_teacher else top_first).cuda()
        return outputs

# %%
rouge = Rouge()

# %% [markdown]
# ## Train

# %%
def train(e, model, optimizer, scheduler, train_iter, vocab_size, grad_clip, lang=TEXT):
    model.train()
    total_loss = 0
    pad = lang.vocab.stoi['<pad>']
    for b, batch in notebook.tqdm(enumerate(train_iter), total=len(train_iter)):
        text, len_text = batch.text
        summary, len_summary = batch.summary
        text, summary = text.cuda(), summary.cuda()
        optimizer.zero_grad()
        output = model(text, summary)
        loss = F.nll_loss(
            output[1:].view(-1, vocab_size),
            summary[1:].contiguous().view(-1),
            ignore_index=pad,
        )
        loss.backward()
        clip_grad_norm_(model.parameters(), grad_clip)
        optimizer.step()
        scheduler.step()
        total_loss += loss.data

        if b % 10 == 0 and b != 0:
            total_loss = total_loss / 100
            print(f'[{b}] [loss: {total_loss}] [loss_exp: {math.exp(total_loss)}]')
            total_loss = 0
        if b % 50 == 0 and b != 0:
            target_summary = text_from_indices(summary.transpose(0, 1)[0])
            output_summary = summarize(text_from_indices(text.transpose(0, 1)[0]))[0]
            print('Original :', text_from_indices(text.transpose(0, 1)[0]))
            print(['-' * 80])
            print('Target :', target_summary)
            print(['-' * 80])
            print('Summary :', output_summary)
            print(['=' * 80])
            scores = calculate_rouge(hypothesis=output_summary, reference=target_summary)
            for key, value in scores[0].items():
                print(f'{key.upper()} [precision] : {np.round(value["p"] * 100, 2)}'
                      '| [recall] : {np.round(value["r"] * 100, 2)}'
                      '| [f-score] : {np.round(value["f"] * 100, 2)}')

# %%
def evaluate(model, val_iter, vocab_size, lang=TEXT):
    with torch.no_grad():
        pad = lang.vocab.stoi['<pad>']
        total_loss = 0
        for b, batch in enumerate(val_iter):
            text, len_text = batch.text
            summary, len_summary = batch.summary
#             text = Variable(text.data, volatile=True)
#             summary = Variable(summary.data, volatile=True)
            text = Variable(text.data.cuda(), volatile=True)
            summary = Variable(summary.data.cuda(), volatile=True)
            output = model(text, summary, teacher_forcing_ratio=0.0)
            loss = F.nll_loss(
                output[1:].view(-1, vocab_size),
                summary[1:].contiguous().view(-1),
                ignore_index=pad,
            )
            total_loss += loss.data
        return total_loss / len(val_iter)

# %%
def calculate_rouge(hypothesis, reference):
    hypothesis = hypothesis.split('<sos>')[1].split('<eos>')[0].strip()
    reference = reference.split('<sos>')[1].split('<eos>')[0].strip()
    scores = rouge.get_scores(hypothesis, reference)
    return scores

# %%
def summarize(text):
    with torch.no_grad():
        sequence = indices_from_text(text).unsqueeze(0)
        sequence_length = sequence.size(1)
        encoder_outputs, encoder_hidden = encoder(sequence.transpose(0, 1))
        
        decoder_input = Variable(torch.LongTensor([indices_from_text(TEXT.init_token)])).cuda()
        hidden = encoder_hidden[:decoder.n_layers]
        summary_words = ['<sos>']
        max_summary_length = int(sequence_length * 0.25)
        decoder_attentions = torch.zeros(max_summary_length, sequence_length)
        
        for idx in range(max_summary_length):
            output, hidden, decoder_attention = decoder(
                decoder_input, 
                hidden, 
                encoder_outputs,
            )
            decoder_attentions[idx, :decoder_attention.size(2)] += decoder_attention.squeeze(0).squeeze(0).cpu().data
            top_v, top_i = output.data.topk(1)
            ni = top_i[0]
            if ni == indices_from_text(TEXT.eos_token):
                break
            else:
                summary_words.append(text_from_indices(ni))
            
            decoder_input = Variable(torch.LongTensor([ni])).cuda()
        summary_words.append(TEXT.eos_token)
        summary = " ".join(summary_words).lstrip()
        return summary, decoder_attentions

# %%
epochs = 10
lr = 0.01
grad_clip = 10.0
scheduler_step_size = 50
scheduler_gamma = 0.75

# %%
hidden_size = 256
embed_size = 128

# %%
print(f'[!] preparing dataset...')
text_size, summary_size = len(TEXT.vocab), len(SUMMARY.vocab)
print(f'[TRAIN]: {len(train_iter)} | {len(train_iter.dataset)}\t [TEST]: {len(test_iter)} | {len(test_iter.dataset)}')
print(f'[TEXT_vocab] & [SUMMARY_vocab] (same) {text_size}')
# Out:
# [!] preparing dataset...
# [TRAIN]: 5014 | 160423	 [TEST]: 627 | 20054
# [TEXT_vocab] & [SUMMARY_vocab] (same) 209439

# %%
print("[!] Instantiating models...")
encoder = EncoderRNN(text_size, embed_size, hidden_size,
                  n_layers=2, dropout=0.5)
decoder = DecoderRNN(embed_size, hidden_size, text_size,
                  n_layers=1, dropout=0.5)
seq2seq = Seq2Seq(encoder, decoder).cuda()
optimizer = optim.Adam(seq2seq.parameters(), lr=lr)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
print(seq2seq)
# Out:
# [!] Instantiating models...
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py:50: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-202-f3cb15979232> in <module>
#       4 decoder = DecoderRNN(embed_size, hidden_size, text_size,
#       5                   n_layers=1, dropout=0.5)
# ----> 6 seq2seq = Seq2Seq(encoder, decoder).cuda()
#       7 optimizer = optim.Adam(seq2seq.parameters(), lr=lr)
#       8 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     221                 # `with torch.no_grad():`
#     222                 with torch.no_grad():
# --> 223                     param_applied = fn(param)
#     224                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     225                 if should_use_set_data:
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     194             raise RuntimeError(
#     195                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 196         _check_driver()
#     197         torch._C._cuda_init()
#     198         _cudart = _load_cudart()
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/cuda/__init__.py in _check_driver()
#      92 def _check_driver():
#      93     if not hasattr(torch._C, '_cuda_isDriverSufficient'):
# ---> 94         raise AssertionError("Torch not compiled with CUDA enabled")
#      95     if not torch._C._cuda_isDriverSufficient():
#      96         if torch._C._cuda_getDriverVersion() == 0:
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
best_val_loss = None
for e in notebook.tqdm(range(1, epochs+1)):
    train(e, seq2seq, optimizer, scheduler, train_iter, text_size, grad_clip, TEXT)
    val_loss = evaluate(seq2seq, val_iter, text_size, TEXT)
    print(f'[Epoch: {e}] val_loss: {val_loss} | val_pp: {math.exp(val_loss)}')

    # Save the model if the validation loss is the best we've seen so far.
    if not best_val_loss or val_loss < best_val_loss:
        print("[!] saving model...")
        if not os.path.isdir(".save"):
            os.makedirs(".save")
        torch.save(seq2seq.state_dict(), './.save/seq2seq_%d.pt' % (e))
        best_val_loss = val_loss
test_loss = evaluate(seq2seq, test_iter, text_size, TEXT)
print(f'[TEST] loss: {test_loss}')

# %%
glob('../working/*')

# %%
import os
os.chdir(r'../working')

# %%
torch.save(seq2seq.state_dict(), 'seq2seq_10.pt')
